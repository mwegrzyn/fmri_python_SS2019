# %% [markdown]
# # Visualisieren eines anatomischen Bildes

# %% [markdown]
# ### Dateiname des strukturellen Bildes

# %%
mpr_file = '../data/sub-01_T1w_space-MNI152NLin2009cAsym_preproc.nii.gz'

# %%
mpr_file
# Out:
# '../data/sub-01_T1w_space-MNI152NLin2009cAsym_preproc.nii.gz'

# %% [markdown]
# ### mit %%bash externes Programm aufrufen

# %%
# %%bash -s $mpr_file
#
# fslview $1

# %% [markdown]
# ### modul zum Anzeigen von MRT-Bildern laden

# %%
from nilearn import plotting

# %% [markdown]
# Wir können das Bild jetzt anzeigen

# %%
plotting.plot_anat(mpr_file)

# %% [markdown]
# Wir können definieren, welche Koordinaten wir zeigen wollen

# %%
plotting.plot_anat(mpr_file,cut_coords=(33,-62,-15))

# %% [markdown]
# Wir können mehrere Schichten der gleichen Ansicht anzeigen

# %%
plotting.plot_anat(mpr_file, # meine datei
                   display_mode='x', # ansicht
                   cut_coords=[-40,-20,20,40] # schnitte
                  )

# %%
plotting.plot_anat(mpr_file, # meine datei
                   display_mode='y', # ansicht
                   cut_coords=[-40,-20,20,40] # schnitte
                  )

# %%
plotting.plot_anat(mpr_file, # meine datei
                   display_mode='z', # ansicht
                   cut_coords=[-40,-20,20,40] # schnitte
                  )

# %% [markdown]
# ### das Ganze mit einer for-Schleife automatisieren

# %% [markdown]
# Beispiel:

# %%
meine_zahlen = [1,2,3] # Liste mit 3 Einträgen

# %%
meine_zahlen
# Out:
# [1, 2, 3]

# %%
type(meine_zahlen)
# Out:
# list

# %%
for diese_zahl in meine_zahlen: # für jeden Eintrag der Liste
    print(diese_zahl) # Zeige den Eintrag
# Out:
# 1
# 2
# 3

# %% [markdown]
# Liste mit Ansichten:

# %%
meine_ansichten = ['x','y','z']

# %%
meine_ansichten
# Out:
# ['x', 'y', 'z']

# %% [markdown]
# Laden von Matplotlib, damit wir nach jedem Durchgang der Schleife einen neuen Plot angezeigt kriegen

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# display_mode wir jetzt durch den jeweiligen Wert von der Schleifen-Variable "diese_ansicht" definiert:

# %%
for diese_ansicht in meine_ansichten:
    print(diese_ansicht)
    plotting.plot_anat(mpr_file, # meine datei
                   display_mode=diese_ansicht, # ansicht
                   cut_coords=(-40,-20,20,40) # schnitte
                  )
    plt.show()
# Out:
# x
# y
# z
